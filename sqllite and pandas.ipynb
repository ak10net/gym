# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sqlite3
import os
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
warnings.filterwarnings('ignore')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
conn = sqlite3.connect('C:\sqlite\Sampledb.db')

c = conn.cursor()

# %%
for row in c.execute("""SELECT * FROM Country LIMIT 2"""):
    print(row)
# Out:
# ('FG', 'Afghanistan', 'Afghanistan', 'Islamic State of Afghanistan', 'AF', 'Afghan afghani', 'Fiscal year end: March 20; reporting period for national accounts data: FY (from 2013 are CY). National accounts data are sourced from the IMF and differ from the Central Statistics Organization numbers due to exclusion of the opium economy.', 'South Asia', 'Low income', 'AF', '2002/03', '', 'Value added at basic prices (VAB)', 'IDA', 'HIPC', 'Country uses the 1993 System of National Accounts methodology.', '', '', '', 'Actual', 'General trade system', 'Consolidated central government', 'General Data Dissemination System (GDDS)', '1979', 'Multiple Indicator Cluster Survey (MICS), 2010/11', 'Integrated household survey (IHS), 2008', '', '2013/14', '', '2013.0', '2000.0')
# ...

# %%
Country = pd.read_sql("""SELECT * FROM Country""", con=conn)

# %%
Country.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0          FG     Afghanistan     Afghanistan
# 1          LB         Albania         Albania
# 2          ZA         Algeria         Algeria
# 3          SM  American Samoa  American Samoa
# 4          DO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  \
# 0                  South Asia            Low income      AF
# ...

# %%
pd.read_sql("""SELECT * FROM Country WHERE CountryCode='FG' """, con=conn)
# Out:
#   CountryCode    ShortName    TableName                      LongName  \
# 0          FG  Afghanistan  Afghanistan  Islamic State of Afghanistan
#
#   Alpha2Code    CurrencyUnit  \
# 0         AF  Afghan afghani
#
#                                         SpecialNotes      Region IncomeGroup  \
# 0  Fiscal year end: March 20; reporting period fo...  South Asia  Low income
#
#   Wb2Code            ...                 GovernmentAccountingConcept  \
# 0      AF            ...             Consolidated central government
#
#                ImfDataDisseminationStandard LatestPopulationCensus  \
# 0  General Data Dissemination System (GDDS)                   1979
#
#                                LatestHouseholdSurvey  \
# 0  Multiple Indicator Cluster Survey (MICS), 2010/11
#
#   SourceOfMostRecentIncomeAndExpenditureData VitalRegistrationComplete  \
# 0    Integrated household survey (IHS), 2008
#
#   LatestAgriculturalCensus LatestIndustrialData LatestTradeData  \
# ...

# %%
pd.read_sql("""SELECT Region, COUNT(*) as [Count] FROM COuntry
        GROUP BY Region ORDER BY 2 DESC""", con=conn)
# Out:
#                        Region  Count
# 0       Europe & Central Asia     57
# 1          Sub-Saharan Africa     48
# 2   Latin America & Caribbean     41
# 3         East Asia & Pacific     36
# 4                                 33
# 5  Middle East & North Africa     21
# 6                  South Asia      8
# 7               North America      3

# %%
pd.read_sql("""SELECT A.CountryCode, B.LatestPopulationCensus,
    B.SourceOfMostRecentIncomeAndExpenditureData,
    B.ShortName
    FROM ( SELECT CountryCode, LatestPopulationCensus, 
    SourceOfMostRecentIncomeAndExpenditureData, ShortName
    FROM Country
    WHERE CountryCode IN ('FG', 'ALB', 'ASM', 'BEL'))
    AS A LEFT JOIN
    (SELECT CountryCode, LatestPopulationCensus,
    SourceOfMostRecentIncomeAndExpenditureData, ShortName
    FROM Country AS A 
    WHERE CountryCode IN ('FG', 'ARM', 'BEL, URY')) AS B ON
    A.CountryCode = B.CountryCode""", con=conn)
# Out:
#   CountryCode LatestPopulationCensus  \
# 0          FG                   1979
#
#   SourceOfMostRecentIncomeAndExpenditureData    ShortName
# 0    Integrated household survey (IHS), 2008  Afghanistan

# %%
pd.read_sql("""SELECT CountryCode,LatestPopulationCensus
               ,SourceOfMostRecentIncomeAndExpenditureData,ShortName
                FROM Country
                WHERE CountryCode IN ('FG','ALB', 'ASM', 'BEL') 
                UNION
                SELECT CountryCode,LatestPopulationCensus
                ,SourceOfMostRecentIncomeAndExpenditureData,ShortName
                FROM Country AS A
                WHERE  CountryCode IN ('FG','ARM', 'URY', 'BEL')
             """, con=conn)
# Out:
#   CountryCode LatestPopulationCensus  \
# 0          FG                   1979
#
#   SourceOfMostRecentIncomeAndExpenditureData    ShortName
# 0    Integrated household survey (IHS), 2008  Afghanistan
